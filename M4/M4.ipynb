# %%
endereçoIP=open("endereçoIP.txt","w")
endereçoIP.write("200.135.80.9\n"
    "192.168.1.1\n"
    "8.35.67.74\n"
    "257.32.4.5\n"
    "85.345.1.2\n"
    "1.2.3.4\n"
    "9.8.234.5\n"
    "192.168.0.256")
endereçoIP.close()

#definir IPs válidos e inválidos da ClasseA
def validar():
    with open("validos.txt","w+") as validos, open("invalidos.txt","w+")as invalidos:
        grupo=[]
        with open("endereçoIP.txt","r") as endereçoIP:
            for IP in endereçoIP.readlines():
                grupo=IP.split('.')
                if(len(grupo)!=4):
                    invalidos.write(IP)
                valores0=int(grupo[0])
                if(valores0>0 and valores0<223 and valores0!=127):
                    valores1=int(grupo[1])
                    if(valores1>=0 and valores1<256):
                        valores2=int(grupo[2])
                        if(valores2>=0 and valores2<256):
                            valores3=int(grupo[3])
                            if(valores3>=0 and valores3<256):
                                validos.write(IP)
                            else:
                                invalidos.write(IP)
                        else:
                            invalidos.write(IP)
                    else:
                        invalidos.write(IP)
                else:
                    invalidos.write(IP)
        endereçoIP.close()
    validos.close()
    invalidos.close()

validar()

#imprimir lista de IDs
with open("validos.txt","r")as validos,open("invalidos.txt","r")as invalidos:
    print("Endereços validos")
    for IP in validos.readlines():
        print(IP)
    print("Endereços invalidos")
    for IP in invalidos.readlines():
        print(IP)
# Out:
# Endereços validos
# 200.135.80.9
#
# 192.168.1.1
#
# 8.35.67.74
#
# 1.2.3.4
#
# 9.8.234.5
#
# Endereços invalidos
# 257.32.4.5
#
# 85.345.1.2
#
# 192.168.0.256

# %%
endereçoIP=open("endereçoIP.txt","w")
endereçoIP.write("200.135.80.9\n"
    "192.168.1.1\n"
    "8.35.67.74\n"
    "257.32.4.5\n"
    "85.345.1.2\n"
    "1.2.3.4\n"
    "9.8.234.5\n"
    "192.168.0.256")
endereçoIP.close()

#definir IPs válidos e inválidos 
def validar():
    with open("validos.txt","w+") as validos, open("invalidos.txt","w+")as invalidos:
        grupo=[]
        with open("endereçoIP.txt","r") as endereçoIP:
            for IP in endereçoIP.readlines():
                grupo=IP.split('.')
                if(len(grupo)!=4):
                    invalidos.write(IP)
                valores0=int(grupo[0])
                #conferir se é valido na Classe A
                if(valores0>0 and valores0<127):
                    valores1=int(grupo[1])
                    if(valores1>=0 and valores1<256):
                        valores2=int(grupo[2])
                        if(valores2>=0 and valores2<256):
                            valores3=int(grupo[3])
                            if(valores3>=0 and valores3<256):
                                validos.write(IP)
                            else:
                                invalidos.write(IP)
                        else:
                            invalidos.write(IP)
                    else:
                        invalidos.write(IP)
                #conferir se é valido na Classe B
                elif(valores0>127 and valores0<192):
                    valores1=int(grupo[1])
                    if(valores1>=0 and valores1<226):
                        valores2=int(grupo[2])
                        if(valores2>=0 and valores2<256):
                            valores3=int(grupo[3])
                            if(valores3>=0 and valores3<256):
                                validos.write(IP)
                            else:
                                invalidos.write(IP)
                        else:
                            invalidos.write(IP)
                    else:
                        invalidos.write(IP)
                #conferir se é valido na Classe C
                elif(valores0>191 and valores0<224):
                    valores1=int(grupo[1])
                    if(valores1>=0 and valores1<226):
                        valores2=int(grupo[2])
                        if(valores2>=0 and valores2<226):
                            valores3=int(grupo[3])
                            if(valores3>0 and valores3<155):
                                validos.write(IP)
                            else:
                                invalidos.write(IP)
                        else:
                            invalidos.write(IP)
                    else:
                        invalidos.write(IP)
                else:
                    invalidos.write(IP)
                
        endereçoIP.close()
    validos.close()
    invalidos.close()

validar()

#imprimir lista de IDs
with open("validos.txt","r")as validos,open("invalidos.txt","r")as invalidos:
    print("Endereços validos")
    for IP in validos.readlines():
        print(IP)
    print("Endereços invalidos")
    for IP in invalidos.readlines():
        print(IP)

# %%
#EX 2 Modulo 1
try:
    a=int(input('A:'))
    b=int(input('B:'))
    print((5*a)+(3*b))
except ValueError:
    print("Entrada inválida.")

# %%
#EX 4 Modulo 1

try:
    x=int(input("Valor de X: "))
    y=int(input("Valor de Y: "))
    operacao=input("+, -, *, /: ")
    if(operacao=="+"):
        print(x+y)
    elif(operacao=="-"):
        print(x-y)
    elif(operacao=="*"):
        print(x*y)
    elif(operacao=="/"):
        print(x/y)
    else:
        print("Operacao incorreta")
except ValueError:
    print("Entrada inválida.")
else:
    print("Tente novamente!")
finally:
    print("Programa Finalizado.")
